# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/Smart Football- Object Detection.v11-od_sgd_optimizer.yolov8.zip'
extraction_path = '/content/'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print(f"'{zip_file_path}' has been extracted to '{extraction_path}'.")
print(f"Contents of '{extraction_path}':")
# !ls -F {extraction_path}
# Out:
# '/content/drive/MyDrive/Smart Football- Object Detection.v11-od_sgd_optimizer.yolov8.zip' has been extracted to '/content/'.
# Contents of '/content/':
# data.yaml  README.dataset.txt	sample_data/  train/
# drive/	   README.roboflow.txt	test/	      valid/

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# load model pretrained
model = YOLO("yolov8n.pt")  # nhẹ, nhanh

# train
model.train(
    data="/content/data.yaml",
    epochs=20,
    imgsz=416,
    batch=32
)
# Out:
# Ultralytics 8.4.38 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/train/images
# !ls /content/valid/images
# Out:
# Streaming output truncated to the last 5000 lines.
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48840_png.rf.e9f07a69d6f983d474cefb043b9efb6b.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48840_png.rf.fe0c18e7067838dd00e711f30c9945b1.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.00dfd3a856274758e89ea712be499460.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.272c760c6cf606423bef0a1ab7d58e93.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.297deb2e0c8bdf42f23e124e082371df.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.4fdcc9eee0c9eba8abbdcd4808c03b13.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.5030ef2fa4729831fbed5c2e582143e3.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.6ad4ccc20d92cf3fbdab229ca0506f18.jpg
# 2015-02-21-18-00Chelsea1-1Burnley2_720p_frame48960_png.rf.9551ac60648b66ef4ee2f31fa54084de.jpg
# ...

# %% [markdown]
# tiếp tục train model sử dụng last model checkpoint đã lưu

# %%
model = YOLO("/content/runs/detect/train2/weights/last.pt")

model.train(
    data="/content/data.yaml",
    epochs=50,
    resume=True
)
# Out:
# Ultralytics 8.4.38 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# test model trên ảnh

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

model.predict(
    source="/content/(1815) FULL MATCH _ Manchester City v Liverpool _ Quarter-Final _ Emirates FA Cup 2025-26 - YouTube and 6 more pages - Personal - Microsoft​ Edge 2026-04-16 20-29-46.mp4",
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/937) /content/(1815) FULL MATCH _ Manchester City v Liverpool _ Quarter-Final _ Emirates FA Cup 2025-26 - YouTube and 6 more pages - Personal - Microsoft​ Edge 2026-04-16 20-29-46.mp4: 256x416 1 ball, 6 goalkeepers, 14 soccer-players, 41.3ms
# ...
